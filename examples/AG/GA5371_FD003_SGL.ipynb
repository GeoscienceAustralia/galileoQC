# %% [markdown]
# # GA5371 QC Vic/SA Gravity - SGL delivery 003

# %% [markdown]
# Author: Mark Dransfield 29 March 2023

# %% [markdown]
# > This notebook uses some Vic/SA survey data to test the AirGravQC Python module. This also serves as a demonstration of the use of `AirGravQC` on gravimeter data.
#
# > Throughout this notebook, text indented like this paragraph, and the paragraphs before and after, indicates commentary intended to explain the purpose, or highlight some feature of, the code and text of the nearby cells. The commentary is an addition to the notebook and is intended to provide extra information to someone planning to use `AirGravQC`.
#
# > Some of the comments are provided as examples and do not necessarily reflect problems that actually occurred in the supplied data. The Vic/SA data were in fact very good.
#
# > The commentary does not document the software but the usual `CMD-I` click on any function will provide the doc-string help.
#
# > The introduction usually contains a summary of the data and results of QC. It should be written according to the needs of the project but might look something like ...

# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook summarises the QC of the FD003 data delivery by SGL for the Vic/SA Gravity Survey flown for Geoscience Australia. The QC is performed under contract GA5371.
#
# The project is SGL project GeoAus21.AUS and GA project number 5618.
#
# The notebook is organised in line with the Technical Specifictions for the survey. Where data has failed a specification it is reported to SGL for rectification.
#
# There were 9,396.9 line-km in FD003 delivered from 14 flights and 71 lines. This example data set is a subset of the original FD003 and contains 1,405.9 line-km in 4 flights and 14 lines.
#
# The rest of this first section is setting up the files for analysis, reporting a summary of the delivered data, and plotting a map of the lines flown against the plan.

# %% [markdown]
# ### QC Colour Coding

# %% [markdown]
# Summary cells are coloured to quickly indicated status against QC. The colours are:

# %% [markdown]
# <div class="alert alert-block alert-success">
# Delivery passed QC.
# <div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Delivery was not checked, or has unusual feature but is nevertheless acceptable.
# <div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Delivery failed QC and problem has been reported for rectification.
# <div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Delivery failed QC and problem might not be readily rectified. This is very rare.
# <div>

# %% [markdown]
# #### Import required modules, and set filenames for data and plan.

# %%
# %matplotlib widget
import sys
import importlib as im
import matplotlib.pyplot as plt
from pathlib import Path
local_docs = "/Users/markdransfield/"
src_path = local_docs + "Documents/GitHub/AirGravQC/src"
sys.path.insert(0, src_path)

import pointfiles as mhd
import qualityAnalysis as qc
import whizzPlot as wp
import gridfiles as erm

data_root = "/Users/markdransfield/Documents/GitHub/AirGravQC/examples/"
dx = Path(data_root + r'AG/FD003_SGL/DLV003_GA5371.xyz')
dh = dx.with_suffix('.hdf5')

# %% [markdown]
# #### Load `xyz` survey data into `hdf` survey file, and set attributes.

# %%
mhd.xyzToHDF(Path(dx), projectName='Victoria and South Australia Gravity')
block_name = 'Part of FD003 for testing'
mhd.updateProject(dh, acquirer='SGL', blockID=block_name)

mhd.updateCoordFrame(dh, lat='LAT', lon='LONG', x='MGA_X', y='MGA_Y', time='FTIME', alt='MGA_Z')
mhd.updateCoordFrame(dh, geoDatum='GDA2020', htDatum='GRS80', projection='MGA', utmz='55')

mhd.updateLineAttributes(dh, line_type='SGL_GA')

mhd.updateChannelAttributes(dh, 'ATMCOR', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'B100s_267_GEOID', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'B100s_267_GRS80', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'B56s_267_GEOID', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'B56s_267_GRS80', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'EOTCOR', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'FA100s_GEOID', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'FA100s_GRS80', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'FA56s_GEOID', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'FA56s_GRS80', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'FACOR_GEOID', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'FACOR_GRS80', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'FTIME', units='s', chan_precision=2)
mhd.updateChannelAttributes(dh, 'FX', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'FY', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'FZ', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'LALT', units='m', chan_precision=2)
mhd.updateChannelAttributes(dh, 'LAT', units='degree', chan_precision=7)
mhd.updateChannelAttributes(dh, 'LATCOR', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'LONG', units='degree', chan_precision=7)
mhd.updateChannelAttributes(dh, 'MGA_X', units='m', chan_precision=2)
mhd.updateChannelAttributes(dh, 'MGA_Y', units='m', chan_precision=2)
mhd.updateChannelAttributes(dh, 'MGA_Z', units='m', chan_precision=2)
mhd.updateChannelAttributes(dh, 'MSL_Z', units='m', chan_precision=2)
mhd.updateChannelAttributes(dh, 'RALT', units='m', chan_precision=2)
mhd.updateChannelAttributes(dh, 'STATCOR', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'TACOR', units='mGal', chan_precision=3)
mhd.updateChannelAttributes(dh, 'V_EAST', units='m/s', chan_precision=3)
mhd.updateChannelAttributes(dh, 'V_NORTH', units='m/s', chan_precision=3)
# Out:
# Accessing XYZ data in /Users/markdransfield/Documents/GitHub/AirGravQC/examples/AG/FD003_SGL/DLV003_GA5371.xyz.
# First few records are:
#    /    ATMCOR B100s_267_GEOID B100s_267_GRS80 B56s_267_GEOID B56s_267_GRS80        DEM        DOY     EOTCOR FA100s_GEOID FA100s_GRS80 FA56s_GEOID FA56s_GRS80 FACOR_GEOID FACOR_GRS80     FLIGHT      FTIME         FX         FY         FZ       LALT             LAT     LATCOR       LINE            LONG      MGA_X      MGA_Y      MGA_Z      MSL_Z       RALT    STATCOR      TACOR     V_EAST    V_NORTH       YEAR
#
#    //Flight 0
#
#    //Date 25/01/01
#
#    Line  2259
#
#
#   Found 29 header records
#   Found 14 lines
#   Found 34 fields
#
# Creating:  /Users/markdransfield/Documents/GitHub/AirGravQC/examples/AG/FD003_SGL/DLV003_GA5371.hdf5
# Setting BlockID = Part of FD003 for testing for DLV003_GA5371.hdf5.
# Setting Acquirer = SGL for DLV003_GA5371.hdf5.
# Changed CoordFrame attribute(s) for DLV003_GA5371.hdf5.
# Changed CoordFrame attribute(s) for DLV003_GA5371.hdf5.
#
# Setting Line attributes for DLV003_GA5371.hdf5 according to the SGL_GA scheme.
#   Line No.       Plan Line No.  Segment No.    Re-flight No.
#   2259.0         2259.0         0              0
#   2261.0         2261.0         0              0
#   2263.0         2263.0         0              0
#   2265.0         2265.0         0              0
#   2267.0         2267.0         0              0
#   2269.0         2269.0         0              0
#   2271.0         2271.0         0              0
#   2273.0         2273.0         0              0
#   2275.0         2275.0         0              0
#   2277.0         2277.0         0              0
#   2279.0         2279.0         0              0
#   2281.0         2281.0         0              0
#   2283.0         2283.0         0              0
#   2303.0         2303.0         0              0
# Changed channel attribute(s) for ATMCOR in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for B100s_267_GEOID in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for B100s_267_GRS80 in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for B56s_267_GEOID in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for B56s_267_GRS80 in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for EOTCOR in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FA100s_GEOID in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FA100s_GRS80 in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FA56s_GEOID in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FA56s_GRS80 in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FACOR_GEOID in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FACOR_GRS80 in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FTIME in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FX in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FY in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for FZ in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for LALT in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for LAT in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for LATCOR in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for LONG in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for MGA_X in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for MGA_Y in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for MGA_Z in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for MSL_Z in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for RALT in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for STATCOR in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for TACOR in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for V_EAST in DLV003_GA5371.hdf5.
# Changed channel attribute(s) for V_NORTH in DLV003_GA5371.hdf5.

# %% [markdown]
# #### Report contents of survey data whizz file.

# %%
mhd.reportWhizz(dh)
# Out:
# Whizz Version 1.0
#     Acquirer: SGL
#     BlockID: Part of FD003 for testing
#     ProjectName: Victoria and South Australia Gravity
#
# Coordinates
#     AltitudeChannel: MGA_Z
#     GeoDatum: GDA2020
#     HeightDatum: GRS80
#     LatitudeChannel: LAT
#     LongitudeChannel: LONG
#     Projection: MGA
#     TimeChannel: FTIME
#     UTMZone: 55
#     XChannel: MGA_X
#     YChannel: MGA_Y
# 14 lines: total distance flown [km] = 1,405.9
#
# 14 lines:
#  ['2259.0', '2261.0', '2263.0', '2265.0', '2267.0', '2269.0', '2271.0', '2273.0', '2275.0', '2277.0', '2279.0', '2281.0', '2283.0', '2303.0']
#
# 34 channels:
#  ['ATMCOR', 'B100s_267_GEOID', 'B100s_267_GRS80', 'B56s_267_GEOID', 'B56s_267_GRS80', 'DEM', 'DOY', 'EOTCOR', 'FA100s_GEOID', 'FA100s_GRS80', 'FA56s_GEOID', 'FA56s_GRS80', 'FACOR_GEOID', 'FACOR_GRS80', 'FLIGHT', 'FTIME', 'FX', 'FY', 'FZ', 'LALT', 'LAT', 'LATCOR', 'LINE', 'LONG', 'MGA_X', 'MGA_Y', 'MGA_Z', 'MSL_Z', 'RALT', 'STATCOR', 'TACOR', 'V_EAST', 'V_NORTH', 'YEAR']

# %% [markdown]
# Report contents of plan whizz File.

# %%
mhd.reportFlights(dh)
# Out:
# Whizz Version 1.0
#     Acquirer: SGL
#     BlockID: Part of FD003 for testing
#     ProjectName: Victoria and South Australia Gravity
#
# 4 flights over 14 lines.
#
# Flights
#     1005
#     1006
#     1013
#     1014

# %%
mhd.reportWhizz(w_plan_file)
# Out:
# Whizz Version 1.0
#     ProjectName: GMEV Planned Drape
#
# Coordinates
#     AltitudeChannel: Drape_m
#     LatitudeChannel: W84_Latitude_deg
#     LongitudeChannel: W84_Longitude_deg
#     XChannel: W84_UTM_55S_X_m
#     YChannel: W84_UTM_55S_Y_m
# 1025 lines: total distance flown [km] = 187,256.8
#
# 1025 lines:
#  ['2001.0', '2003.0', '2005.0', '2007.0', '2009.0', '201.0', '2011.0', '2013.0', '2015.0', '2017.0', '2019.0', '202.0', '2021.0', '2023.0', '2025.0', '2027.0', '2029.0', '203.0', '2031.0', '2033.0', '2035.0', '2037.0', '2039.0', '204.0', '2041.0', '2043.0', '2045.0', '2047.0', '2049.0', '205.0', '2051.0', '2053.0', '2055.0', '2057.0', '2059.0', '206.0', '2061.0', '2063.0', '2065.0', '2067.0', '2069.0', '207.0', '2071.0', '2073.0', '2075.0', '2077.0', '2079.0', '208.0', '2081.0', '2083.0', '2085.0', '2087.0', '2089.0', '209.0', '2091.0', '2093.0', '2095.0', '2097.0', '2099.0', '210.0', '2101.0', '2103.0', '2105.0', '2107.0', '2109.0', '211.0', '2111.0', '2113.0', '2115.0', '2117.0', '2119.0', '212.0', '2121.0', '2123.0', '2125.0', '2127.0', '2129.0', '213.0', '2131.0', '2133.0', '2135.0', '2137.0', '2139.0', '2139.1', '214.0', '2141.0', '2141.1', '2143.0', '2143.1', '2145.0', '2145.1', '2147.0', '2147.1', '2148.0', '2149.0', '2149.1', '215.0', '2150.0', '2151.0', '2151.1', '2152.0', '2153.0', '2153.1', '2154.0', '2155.0', '2155.1', '2156.0', '2157.0', '2157.1', '2158.0', '2159.0', '2159.1', '216.0', '2160.0', '2161.0', '2161.1', '2162.0', '2163.0', '2163.1', '2164.0', '2165.0', '2165.1', '2166.0', '2167.0', '2167.1', '2168.0', '2169.0', '2169.1', '217.0', '2170.0', '2171.0', '2171.1', '2172.0', '2173.0', '2173.1', '2174.0', '2175.0', '2175.1', '2176.0', '2177.0', '2177.1', '2178.0', '2179.0', '2179.1', '218.0', '2180.0', '2181.0', '2181.1', '2182.0', '2183.0', '2183.1', '2184.0', '2185.0', '2185.1', '2186.0', '2187.0', '2187.1', '2188.0', '2189.0', '2189.1', '2190.0', '2191.0', '2191.1', '2192.0', '2193.0', '2193.1', '2194.0', '2195.0', '2195.1', '2196.0', '2197.0', '2197.1', '2198.0', '2199.0', '2199.1', '2200.0', '2201.0', '2201.1', '2202.0', '2203.0', '2203.1', '2204.0', '2205.0', '2205.1', '2206.0', '2207.0', '2207.1', '2208.0', '2209.0', '2209.1', '2210.0', '2211.0', '2211.1', '2212.0', '2213.0', '2213.1', '2214.0', '2215.0', '2215.1', '2216.0', '2217.0', '2217.1', '2218.0', '2219.0', '2219.1', '2220.0', '2221.0', '2221.1', '2222.0', '2223.0', '2223.1', '2224.0', '2225.0', '2225.1', '2226.0', '2227.0', '2227.1', '2228.0', '2229.0', '2229.1', '2230.0', '2231.0', '2231.1', '2232.0', '2233.0', '2233.1', '2234.0', '2235.0', '2235.1', '2236.0', '2237.0', '2237.1', '2238.0', '2239.0', '2239.1', '2240.0', '2241.0', '2241.1', '2242.0', '2243.0', '2243.1', '2244.0', '2245.0', '2245.1', '2246.0', '2247.0', '2247.1', '2248.0', '2249.0', '2249.1', '2250.0', '2251.0', '2251.1', '2252.0', '2253.0', '2253.1', '2254.0', '2255.0', '2255.1', '2256.0', '2257.0', '2257.1', '2258.0', '2259.0', '2259.1', '2259.5', '2260.0', '2261.0', '2261.1', '2261.5', '2262.0', '2263.0', '2263.1', '2263.5', '2264.0', '2265.0', '2265.1', '2265.5', '2265.6', '2266.0', '2267.0', '2267.1', '2267.5', '2267.6', '2268.0', '2269.0', '2269.1', '2269.5', '2269.6', '2270.0', '2271.0', '2271.1', '2271.5', '2271.6', '2272.0', '2273.0', '2273.1', '2273.5', '2273.6', '2274.0', '2275.0', '2275.1', '2275.5', '2275.6', '2276.0', '2277.0', '2277.1', '2277.5', '2277.6', '2278.0', '2279.0', '2279.1', '2279.5', '2279.6', '2280.0', '2281.0', '2281.1', '2281.5', '2281.6', '2282.0', '2283.0', '2283.1', '2283.5', '2283.6', '2284.0', '2285.0', '2285.1', '2285.5', '2286.0', '2287.0', '2287.1', '2287.5', '2288.0', '2289.0', '2289.1', '2289.5', '2290.0', '2291.0', '2291.1', '2291.5', '2292.0', '2293.0', '2293.1', '2293.5', '2294.0', '2295.0', '2295.1', '2295.5', '2296.0', '2297.0', '2297.1', '2297.5', '2298.0', '2299.0', '2299.1', '2299.5', '2300.0', '2301.0', '2301.1', '2301.5', '2302.0', '2303.0', '2303.1', '2303.5', '2304.0', '2305.0', '2305.1', '2305.5', '2306.0', '2307.0', '2307.1', '2307.5', '2308.0', '2309.0', '2309.1', '2309.5', '2310.0', '2311.0', '2311.1', '2311.5', '2312.0', '2313.0', '2313.1', '2313.5', '2314.0', '2315.0', '2315.1', '2315.5', '2316.0', '2317.0', '2317.1', '2317.5', '2318.0', '2319.0', '2319.1', '2319.5', '2320.0', '2321.0', '2321.1', '2321.5', '2322.0', '2323. ...
#
# 8 channels:
#  ['Clearance_m', 'Drape_m', 'Line', 'Terrain_m', 'W84_Latitude_deg', 'W84_Longitude_deg', 'W84_UTM_55S_X_m', 'W84_UTM_55S_Y_m']

# %% [markdown]
# Make a lines map.

# %%
# %matplotlib widget
wp.linesMap([dh], whizzPlanFile=w_plan_file)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# A quick look at the Bouguer gravity. (Sadly reversed - whizz bug!)

# %%
im.reload(erm)
erm.display_grid(boug_grid_path, 'Bouguer Gravity')
# Out:
# 32 bit precision
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <div class="alert alert-block alert-success">
# Data imported successfully.
# <div>

# %% [markdown]
# ***

# %% [markdown]
# ## Quality checks

# %% [markdown]
# The following sections describe the quality checks on the data. The data were delivered in XYZ format, an ASCII text fixed-width column format, separated by survey line number. All data were provided to a decimal precision better than nominal accuracy. Some of the following sections refer to an “aspect” and this means an aspect described in the survey contract.
#
# Quality checks are reported by specification and are marked “pass” if all data passed, “accept” if the data were accepted despite minor deviations from specification or if the deviations were for safety reasons, “fail” if one or more lines require re-flying, or “NA” if the specification is not applicable to the delivered data.

# %% [markdown]
# ### Survey Data

# %% [markdown]
# See the report for details.

# %% [markdown]
# #### Line direction
# <div class="alert alert-block alert-success">
# Line direction: PASS
# <div>

# %%
qc.checkHeading(dh, 52.0, tolerance=10)
# Out:
# limits: 42.0, 62.0

# %% [markdown]
# L 2345.51 deviates around a smoke plume (power station). Accepted.
# L 256.3 is good. The result reflects a bug in my s/w. Accepted

# %% [markdown]
# ***

# %% [markdown]
# #### Line spacing
# <div class="alert alert-block alert-success">
# Line Spacing: PASS
# <div>

# %%
qc.checkXYPlan(w_plan_file, dh, allowance=35.0, maxCounter=20)
# Out:
# Processing line 2259.5.
# Processing line 2261.5.
# Processing line 2263.5.
# Processing line 2265.5.
# Processing line 2265.6.
# Processing line 2267.5.
# Processing line 2267.6.
# Processing line 2269.5.
# Processing line 2269.6.
# Processing line 2271.5.
# Processing line 2271.6.
# Processing line 2273.5.
# Processing line 2273.6.
# Processing line 2275.5.
# Processing line 2275.51.
# Processing line 2275.6.
# Processing line 2277.5.
# Processing line 2277.51.
# Processing line 2277.6.
# Processing line 2279.5.
# Processing line 2279.6.
# Processing line 2281.5.
# Processing line 2281.51.
# Processing line 2281.52.
# Processing line 2281.6.
# Processing line 2283.5.
# Processing line 2283.51.
# Processing line 2283.6.
# Processing line 2285.5.
# Processing line 2285.51.
# Processing line 2287.5.
# Processing line 2287.51.
# Processing line 2289.5.
# Processing line 2289.51.
# Processing line 2291.5.
# Processing line 2291.51.
# Processing line 2293.5.
# Processing line 2293.51.
# Processing line 2295.5.
# Processing line 2295.51.
# Processing line 2297.5.
# Processing line 2297.51.
# Processing line 2299.5.
# Processing line 2299.51.
# Processing line 2301.5.
# Processing line 2301.51.
# Processing line 2303.5.
# Processing line 2305.5.
# Processing line 2305.51.
# Processing line 2307.5.
# Processing line 2307.51.
# Processing line 2309.5.
# Processing line 2311.5.
# Processing line 2313.5.
# Processing line 2313.51.
# Processing line 2315.5.
# Processing line 2315.51.
# Processing line 2317.5.
# Processing line 2317.51.
# Processing line 2319.5.
# Processing line 2321.5.
# Processing line 2323.5.
# Processing line 2325.5.
# Processing line 2327.5.
# Processing line 2329.5.
# Processing line 2331.5.
# Processing line 2333.5.
# Processing line 2333.51.
# Processing line 2335.5.
# Processing line 2335.51.
# Processing line 2337.5.
# Processing line 2339.5.
# Processing line 2341.5.
# Processing line 2343.5.
# Processing line 2343.51.
# Processing line 2345.5.
# Processing line 2345.51.
# Processing line 2347.5.
# Processing line 2349.5.
# Processing line 2349.51.
# Processing line 2351.5.
# Processing line 2351.51.
# Processing line 2353.5.
# Processing line 2355.5.
# Processing line 2355.51.
# Processing line 2357.5.
# Processing line 2357.51.
# Processing line 2359.5.
# Processing line 2359.51.
# Processing line 2361.5.
# Processing line 2361.51.
# Processing line 2363.5.
# Processing line 2363.51.
# Processing line 2365.5.
# Processing line 2365.51.
# Processing line 2367.5.
# Processing line 2367.51.
# Processing line 2369.5.
# Processing line 2369.51.
# Processing line 2371.5.
# Processing line 2371.51.
# Processing line 2373.5.
# Processing line 2373.51.
# Processing line 2375.5.
# Processing line 2375.51.
# Processing line 2377.5.
# Processing line 2379.5.
# Processing line 2381.5.
# Processing line 2383.5.
# Processing line 2385.5.
# Processing line 2387.5.
# Processing line 2389.5.
# Processing line 2391.5.
# Processing line 2393.5.
# Processing line 2395.5.
# Processing line 2397.5.
# Processing line 2399.5.
# Processing line 2401.5.
# Processing line 2403.5.
# Processing line 2405.5.
# Processing line 2407.5.
# Processing line 2409.5.
# Processing line 2411.5.
# Processing line 2413.5.
# Processing line 2415.5.
# Processing line 2417.5.
# Processing line 2419.5.
# Processing line 2421.5.
# Processing line 2423.5.
# Processing line 2425.5.
# Processing line 2427.5.
# Processing line 2429.5.
# Processing line 2431.5.
# Processing line 2433.5.
# Processing line 2435.5.
# Processing line 256.3.
# Processing line 2581.4.
# Processing line 2581.41.
# Processing line 2583.4.
# Processing line 2583.41.
# Processing line 2585.4.
# Processing line 2585.41.
# Processing line 2587.4.
# Processing line 2589.4.
# Processing line 2589.41.
# Processing line 2591.4.
# Processing line 2591.41.
# Processing line 2593.4.
# Processing line 2595.4.
# Processing line 2597.4.
# Processing line 2599.4.
# Processing line 2599.41.
# Processing line 2601.4.
# Processing line 2603.4.
# Processing line 2605.4.
# Processing line 2607.3.
# Processing line 2607.4.
# Processing line 2609.3.
# Processing line 2609.4.
# Processing line 2611.3.
# Processing line 2611.4.
# Processing line 2613.3.
# Processing line 2613.4.
# Processing line 2615.3.
# Processing line 2615.4.
# Processing line 2617.3.
# Processing line 2617.31.
# Processing line 2617.4.
# Processing line 2619.3.
# Processing line 2619.4.
# Processing line 2619.41.
# Processing line 2621.3.
# Processing line 2621.31.
# Processing line 2621.4.
# Processing line 2621.41.
# Processing line 2623.3.
# Processing line 2623.31.
# Processing line 2623.4.
# Processing line 2625.3.
# Processing line 2625.31.
# Processing line 2625.4.
# Processing line 2627.3.
# Processing line 2627.4.
# Processing line 2629.3.
# Processing line 2629.4.
# Processing line 2631.3.
# Processing line 2631.31.
# Processing line 2631.4.
# Processing line 2633.3.
# Processing line 2633.4.
# Processing line 2635.3.
# Processing line 2635.4.
# Processing line 2637.3.
# Processing line 2637.4.
# Processing line 2639.3.
# Processing line 2639.4.
# Processing line 2641.3.
# Processing line 2641.4.
# Processing line 2643.3.
# Processing line 2643.4.
# Processing line 2645.3.
# Processing line 2645.4.
# Processing line 2647.3.
# Processing line 2647.4.
# Processing line 2649.3.
# Processing line 2649.4.
# Processing line 2651.3.
# Processing line 2651.4.
# Processing line 2651.41.
# Processing line 2653.3.
# Processing line 2653.4.
# Processing line 2655.3.
# Processing line 2655.4.
# Processing line 2655.41.
# Processing line 2657.3.
# Processing line 2657.31.
# Processing line 2657.4.
# Processing line 2657.42.
# Processing line 2657.43.
# Processing line 2659.3.
# Processing line 2659.4.
# Processing line 2659.41.
# Processing line 2659.42.
# Processing line 2661.3.
# Processing line 2661.31.
# Processing line 2661.4.
# Processing line 2661.41.
# Processing line 2663.3.
# Processing line 2663.31.
# Processing line 2663.4.
# Processing line 2663.41.
# Processing line 2663.42.
# Processing line 2665.3.
# Processing line 2665.4.
# Processing line 2665.41.
# Processing line 2667.3.
# Processing line 2667.4.
# Processing line 2667.41.
# Processing line 2669.3.
# Processing line 2669.4.
# Processing line 2669.41.
# Processing line 2669.42.
# Processing line 2671.3.
# Processing line 2671.4.
# Processing line 2671.41.
# Processing line 2673.3.
# Processing line 2673.4.
# Processing line 2673.41.
# Processing line 2675.3.
# Processing line 2675.4.
# Processing line 2677.3.
# Processing line 2677.4.
# Processing line 2679.3.
# Processing line 2679.4.
# Processing line 2681.3.
# Processing line 2681.4.
# Processing line 2681.41.
# Processing line 2683.3.
# Processing line 2683.4.
# Processing line 2683.41.
# Processing line 2683.42.
# Processing line 2685.3.
# Processing line 2685.31.
# Processing line 2685.4.
# Processing line 2687.3.
# Processing line 2687.4.
# Processing line 2689.3.
# Processing line 2689.4.
# Processing line 2689.41.
# Processing line 2691.3.
# Processing line 2691.4.
# Processing line 2691.41.
# Processing line 2693.3.
# Processing line 2693.31.
# Processing line 2693.4.
# Processing line 2693.41.
# Processing line 2695.3.
# Processing line 2695.4.
# Processing line 2695.41.
# Processing line 2697.3.
# Processing line 2697.4.
# Processing line 2697.41.
# Processing line 2699.3.
# Processing line 2699.4.
# Processing line 2701.3.
# Processing line 2701.4.
# Processing line 2703.3.
# Processing line 2703.31.
# Processing line 2703.4.
# Processing line 2703.41.
# Processing line 2705.3.
# Processing line 2705.4.
# Processing line 2705.41.
# Processing line 2707.3.
# Processing line 2707.4.
# Processing line 2707.41.
# Processing line 2709.3.
# Processing line 2709.4.
# Processing line 2709.41.
# Processing line 2711.3.
# Processing line 2711.4.
# Processing line 2711.41.
# Processing line 2713.3.
# Processing line 2713.4.
# Processing line 2715.3.
# Processing line 2715.4.
# Processing line 2717.3.
# Processing line 2717.4.
# Processing line 2719.3.
# Processing line 2719.4.
# Processing line 2721.3.
# Processing line 2721.4.
# Processing line 2723.3.
# Processing line 2723.4.
# Processing line 2725.3.
# Processing line 2725.4.
# Processing line 2727.3.
# Processing line 2727.4.
# Processing line 2729.4.
# Processing line 2731.4.
# Processing line 2733.4.
# Processing line 2735.4.
# Processing line 2735.41.
#
# 0 lines not in plan and not checked.
#
# 3 lines with horizontal exceedances.
#
# L 2345.51 deviates more than 35.0 m for 87 fids (2438 m). Max exceedance = 270.
#   From (463633 E 5766721 N) to (461712 E 5765218 N).
# L 2351.5 deviates more than 35.0 m for 22 fids (650 m). Max exceedance = 73.
#   From (470082 E 5775642 N) to (469619 E 5775186 N).
# L 2661.3 deviates more than 35.0 m for 27 fids (848 m). Max exceedance = 41.
#   From (273437 E 5818814 N) to (272771 E 5818288 N).

# %% [markdown]
# Of the 27 lines that strictly fail this spec, almost all are very minor exceedances and not worthy of re-flight. Four deserve a closer look, with peak exceedances greater than 10 m. These are:
# 2345.51 - deviation to avoid a smokestack. ACCEPT
# 2351.5 - deviation to avoid power station plume. Also partially recovered by 2351.51. ACCEPT
# 2661.3 - deviation for ATC (occurs right alongside Bacchus Marsh airport). ACCEPT
# 2707.3 - small and short exceedance near end of line and outside survey boundary. ACCEPT

# %% [markdown]
# #### Closest approach to terrain
# <div class="alert alert-block alert-success">
# Closest approach: PASS
# <div>

# %%
im.reload(qc)
qc.checkClearance(dh, 165.0, altitude_chan='MGA_Z', terrain_chan='DEM', allowance=35.0, only_low=True)
# Out:
# Number of failed lines = 0.

# %% [markdown]
# #### Survey height against plan
# <div class="alert alert-block alert-success">
# Survey height: PASS
# <div>

# %%
qc.checkVertPlan(w_plan_file, dh, planZ='Drape_m', measZ='MGA-Z', 
                 allowance=25.0, maxCounter=10, plot_flag=False)
# Out:
# L 2321.5 deviates more than 25.0 m for 136 fids (4138 m). Max exceedance = 46.9 m.
#   From (460070 E, 5748673 N) to (463332 E, 5751220 N).
# L 2343.51 deviates more than 25.0 m for 147 fids (4282 m). Max exceedance = 147.3 m.
#   From (461942 E, 5764087 N) to (465317 E, 5766723 N).
# L 2345.51 deviates more than 25.0 m for 191 fids (5802 m). Max exceedance = 153.2 m.
#   From (543381 E, 5828831 N) to (538801 E, 5825269 N).
# L 2605.4 deviates more than 25.0 m for 12 fids (370 m). Max exceedance = 4.4 m.
#   From (516406 E, 5972622 N) to (516114 E, 5972394 N).
# L 2605.4 deviates more than 25.0 m for 63 fids (1938 m). Max exceedance = 32.9 m.
#   From (455728 E, 5925330 N) to (454198 E, 5924141 N).
# L 2619.4 deviates more than 25.0 m for 24 fids (753 m). Max exceedance = 11.5 m.
#   From (376813 E, 5872718 N) to (377415 E, 5873170 N).
# L 2631.3 deviates more than 25.0 m for 22 fids (695 m). Max exceedance = 9.4 m.
#   From (267310 E, 5794980 N) to (267866 E, 5795396 N).
# L 2655.4 deviates more than 25.0 m for 21 fids (640 m). Max exceedance = 3.4 m.
#   From (383840 E, 5901012 N) to (383337 E, 5900616 N).
# L 2657.4 deviates more than 25.0 m for 84 fids (2763 m). Max exceedance = 118.2 m.
#   From (351608 E, 5877178 N) to (353795 E, 5878865 N).
# L 2665.41 deviates more than 25.0 m for 131 fids (3950 m). Max exceedance = 78.4 m.
#   From (426047 E, 5940236 N) to (422930 E, 5937808 N).
# L 2667.41 deviates more than 25.0 m for 24 fids (735 m). Max exceedance = 4.9 m.
#   From (485802 E, 5988078 N) to (486380 E, 5988532 N).
# L 2673.41 deviates more than 25.0 m for 95 fids (2901 m). Max exceedance = 45.3 m.
#   From (382753 E, 5911565 N) to (380467 E, 5909780 N).
# L 2679.4 deviates more than 25.0 m for 60 fids (1757 m). Max exceedance = 27.1 m.
#   From (486253 E, 5996033 N) to (487641 E, 5997110 N).
# L 2679.4 deviates more than 25.0 m for 19 fids (543 m). Max exceedance = 9.2 m.
#   From (487756 E, 5997200 N) to (488187 E, 5997532 N).
# L 2679.4 deviates more than 25.0 m for 49 fids (1445 m). Max exceedance = 23.3 m.
#   From (497433 E, 6004740 N) to (498569 E, 6005634 N).
# L 2683.4 deviates more than 25.0 m for 66 fids (1967 m). Max exceedance = 65.1 m.
#   From (462225 E, 5979845 N) to (460675 E, 5978634 N).
# L 2705.3 deviates more than 25.0 m for 58 fids (1654 m). Max exceedance = 59.1 m.
#   From (238099 E, 5819116 N) to (236794 E, 5818099 N).
# L 2705.41 deviates more than 25.0 m for 18 fids (542 m). Max exceedance = 3.3 m.
#   From (368016 E, 5920367 N) to (368445 E, 5920698 N).
#
# 0 lines not in plan and not checked.
#
# Total number of exceedances = 18 over 15 erroneous lines.

# %% [markdown]
# SGL report a longer list but they include deviations of short extent that I can accept. Of my list above, three (2619.4, 2667.41, 2673.41) are very minor and can be ignored. Seven are for unavoidable reasons (towers, smokestacks) or reasons (ATC requests) that will likely occur again if a re-fly is attempted; these are 2321.5, 2343.51, 2345.51, 2665.41, 2679.4, 2683.4, 2705.3.
#
# This leaves 2605.4 (fire), 2631.3 (cloud), 2657.4 (cloud).<br>
# > 2605.4 - clearance is ~650 m, so a ~65 m difference is equivalent to ~15 m at 165 m clearance. ACCEPT.<br>
# 2631.3 - exceedance length of 1235 m is only just over 1000 m. Maximum exceedance of 14.4 m is small. ACCEPT<br>
# 2657.4 - was re-flown in 2657.42. ACCEPT

# %%
# %matplotlib widget
qc.checkVertPlan(w_plan_file, dh, planZ='Drape_m', measZ='MGA-Z', allowance=20.0, maxCounter=35, plot_flag=True)
# Out:
# L 2321.5 deviates more than 20.0 m for 148 fids (4503 m). Max exceedance = 51.9 m.
#   From (459949 E, 5748581 N) to (463498 E, 5751352 N).
# L 2343.51 deviates more than 20.0 m for 154 fids (4487 m). Max exceedance = 152.3 m.
#   From (461829 E, 5763999 N) to (465365 E, 5766761 N).
# L 2345.51 deviates more than 20.0 m for 201 fids (6103 m). Max exceedance = 158.2 m.
#   From (543428 E, 5828868 N) to (538611 E, 5825121 N).
# L 2605.4 deviates more than 20.0 m for 70 fids (2154 m). Max exceedance = 37.9 m.
#   From (455777 E, 5925368 N) to (454077 E, 5924045 N).
# L 2619.4 deviates more than 20.0 m for 52 fids (1622 m). Max exceedance = 16.5 m.
#   From (376235 E, 5872247 N) to (377514 E, 5873244 N).
# L 2631.3 deviates more than 20.0 m for 39 fids (1235 m). Max exceedance = 14.4 m.
#   From (266959 E, 5794702 N) to (267939 E, 5795455 N).
# L 2657.4 deviates more than 20.0 m for 86 fids (2828 m). Max exceedance = 123.2 m.
#   From (351608 E, 5877178 N) to (353847 E, 5878905 N).
# L 2665.41 deviates more than 20.0 m for 139 fids (4189 m). Max exceedance = 83.4 m.
#   From (426095 E, 5940272 N) to (422790 E, 5937698 N).
# L 2667.41 deviates more than 20.0 m for 40 fids (1229 m). Max exceedance = 9.9 m.
#   From (485636 E, 5987948 N) to (486606 E, 5988702 N).
# L 2673.41 deviates more than 20.0 m for 112 fids (3417 m). Max exceedance = 50.3 m.
#   From (382901 E, 5911683 N) to (380208 E, 5909579 N).
# L 2679.4 deviates more than 20.0 m for 92 fids (2679 m). Max exceedance = 32.1 m.
#   From (486113 E, 5995925 N) to (488231 E, 5997566 N).
# L 2679.4 deviates more than 20.0 m for 56 fids (1652 m). Max exceedance = 28.3 m.
#   From (497316 E, 6004651 N) to (498616 E, 6005670 N).
# L 2683.4 deviates more than 20.0 m for 71 fids (2119 m). Max exceedance = 70.1 m.
#   From (462250 E, 5979864 N) to (460580 E, 5978559 N).
# L 2705.3 deviates more than 20.0 m for 62 fids (1770 m). Max exceedance = 64.1 m.
#   From (238143 E, 5819150 N) to (236747 E, 5818062 N).
#
# 0 lines not in plan and not checked.
#
# Total number of exceedances = 14 over 13 erroneous lines.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
wp.plotLineXChannels(dh, '2657.4', 'MGA-X', 'MGA-Z', 'LALT', xOffset=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Height difference at crossover
# <div class="alert alert-block alert-info">
# No control lines so NA
# <div>

# %% [markdown]
# No control lines flown yet so NA.

# %% [markdown]
# #### Crossover intersections
# <div class="alert alert-block alert-info">
# No control lines so NA
# <div>

# %% [markdown]
# No control lines flown yet so NA.

# %% [markdown]
# #### Minimum line length
# <div class="alert alert-block alert-success">
# Minimum line length: PASS
# <div>

# %%
qc.checkLineLengths(dh, min_len=38.0)
# Out:
# Number failed lines = 0

# %% [markdown]
# #### Line padding
# <div class="alert alert-block alert-success">
# PASS
# <div>

# %% [markdown]
# Checked by overlaying the plan (plan 9) over the actual flight lines. All good.

# %% [markdown]
# #### Overlaps
# <div class="alert alert-block alert-success">
# PASS
# <div>

# %%
qc.checkOverlaps(dh)
# Out:
# Repeat line 2275.5, 2275.51: overlap by 7829 m.
# Repeat line 2277.5, 2277.51: overlap by 7841 m.
# ERROR: Repeat line 2281.5, 2281.51: overlap 0 m < 7600.0.
# Repeat line 2281.5, 2281.52: overlap by 15356 m.
# Repeat line 2281.51, 2281.52: overlap by 15361 m.
# Repeat line 2283.5, 2283.51: overlap by 15344 m.
# Repeat line 2285.5, 2285.51: overlap by 15301 m.
# Repeat line 2287.5, 2287.51: overlap by 14822 m.
# Repeat line 2289.5, 2289.51: overlap by 15273 m.
# Repeat line 2291.5, 2291.51: overlap by 19695 m.
# Repeat line 2293.5, 2293.51: overlap by 11706 m.
# Repeat line 2295.5, 2295.51: overlap by 15419 m.
# Repeat line 2297.5, 2297.51: overlap by 15285 m.
# Repeat line 2299.5, 2299.51: overlap by 15467 m.
# Repeat line 2301.5, 2301.51: overlap by 18267 m.
# Repeat line 2305.5, 2305.51: overlap by 25403 m.
# Repeat line 2307.5, 2307.51: overlap by 36846 m.
# Repeat line 2313.5, 2313.51: overlap by 10205 m.
# Repeat line 2315.5, 2315.51: overlap by 15680 m.
# Repeat line 2317.5, 2317.51: overlap by 8742 m.
# Repeat line 2333.5, 2333.51: overlap by 16733 m.
# Repeat line 2335.5, 2335.51: overlap by 8844 m.
# Repeat line 2343.5, 2343.51: overlap by 15272 m.
# Repeat line 2345.5, 2345.51: overlap by 11452 m.
# Repeat line 2349.5, 2349.51: overlap by 15910 m.
# Repeat line 2351.5, 2351.51: overlap by 19199 m.
# Repeat line 2355.5, 2355.51: overlap by 15767 m.
# Repeat line 2357.5, 2357.51: overlap by 17649 m.
# Repeat line 2359.5, 2359.51: overlap by 15353 m.
# Repeat line 2361.5, 2361.51: overlap by 15335 m.
# Repeat line 2363.5, 2363.51: overlap by 16171 m.
# Repeat line 2365.5, 2365.51: overlap by 15418 m.
# Repeat line 2367.5, 2367.51: overlap by 15197 m.
# Repeat line 2369.5, 2369.51: overlap by 17000 m.
# Repeat line 2371.5, 2371.51: overlap by 10129 m.
# Repeat line 2373.5, 2373.51: overlap by 15399 m.
# Repeat line 2375.5, 2375.51: overlap by 15469 m.
# Repeat line 2581.4, 2581.41: overlap by 15454 m.
# Repeat line 2583.4, 2583.41: overlap by 15628 m.
# Repeat line 2585.4, 2585.41: overlap by 15305 m.
# Repeat line 2589.4, 2589.41: overlap by 15229 m.
# Repeat line 2591.4, 2591.41: overlap by 15508 m.
# Repeat line 2599.4, 2599.41: overlap by 15196 m.
# Repeat line 2617.3, 2617.31: overlap by 19115 m.
# Repeat line 2619.4, 2619.41: overlap by 15393 m.
# Repeat line 2621.3, 2621.31: overlap by 17472 m.
# Repeat line 2621.4, 2621.41: overlap by 22912 m.
# Repeat line 2623.3, 2623.31: overlap by 15248 m.
# Repeat line 2625.3, 2625.31: overlap by 22715 m.
# Repeat line 2631.3, 2631.31: overlap by 21677 m.
# Repeat line 2651.4, 2651.41: overlap by 16652 m.
# Repeat line 2655.4, 2655.41: overlap by 19009 m.
# Repeat line 2657.3, 2657.31: overlap by 15228 m.
# All of line 2657.4 in 2657.42: length 62353 m.
# ERROR: Repeat line 2657.4, 2657.43: overlap 0 m < 7600.0.
# Repeat line 2657.42, 2657.43: overlap by 25309 m.
# Repeat line 2659.4, 2659.41: overlap by 15285 m.
# Repeat line 2659.4, 2659.42: overlap by 27958 m.
# ERROR: Repeat line 2659.41, 2659.42: overlap 0 m < 7600.0.
# Repeat line 2661.3, 2661.31: overlap by 26244 m.
# Repeat line 2661.4, 2661.41: overlap by 26812 m.
# Repeat line 2663.3, 2663.31: overlap by 21680 m.
# Repeat line 2663.4, 2663.41: overlap by 17660 m.
# Repeat line 2663.4, 2663.42: overlap by 15325 m.
# ERROR: Repeat line 2663.41, 2663.42: overlap 0 m < 7600.0.
# Repeat line 2665.4, 2665.41: overlap by 26174 m.
# Repeat line 2667.4, 2667.41: overlap by 22544 m.
# ERROR: Repeat line 2669.4, 2669.41: overlap 0 m < 7600.0.
# Repeat line 2669.4, 2669.42: overlap by 22943 m.
# Repeat line 2669.41, 2669.42: overlap by 31958 m.
# Repeat line 2671.4, 2671.41: overlap by 22339 m.
# Repeat line 2673.4, 2673.41: overlap by 21469 m.
# Repeat line 2681.4, 2681.41: overlap by 15238 m.
# Repeat line 2683.4, 2683.41: overlap by 13339 m.
# Repeat line 2683.4, 2683.42: overlap by 97293 m.
# All of line 2683.41 in 2683.42: length 174838 m.
# Repeat line 2685.3, 2685.31: overlap by 25777 m.
# Repeat line 2689.4, 2689.41: overlap by 15340 m.
# Repeat line 2691.4, 2691.41: overlap by 15235 m.
# Repeat line 2693.3, 2693.31: overlap by 23273 m.
# Repeat line 2693.4, 2693.41: overlap by 17252 m.
# Repeat line 2695.4, 2695.41: overlap by 23338 m.
# Repeat line 2697.4, 2697.41: overlap by 15304 m.
# Repeat line 2703.3, 2703.31: overlap by 21804 m.
# Repeat line 2703.4, 2703.41: overlap by 15287 m.
# Repeat line 2705.4, 2705.41: overlap by 15318 m.
# Repeat line 2707.4, 2707.41: overlap by 18886 m.
# Repeat line 2709.4, 2709.41: overlap by 20915 m.
# Repeat line 2711.4, 2711.41: overlap by 21410 m.
# Repeat line 2735.4, 2735.41: overlap by 26489 m.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 90 coincident lines found.

# %% [markdown]
# Five lines had zero overlap with another on the same planned line:
# > 2281.5, 2281.51 - both properly overlapped by .52<br>
# 2657.4, 2657.43 - 2657.4 completely re-flown by .42<br>
# 2659.41, 2659.42 - both properly overlapped by .40<br>
# 2663.41, 2663.42 - both properly overlapped by .40<br>
# 2669.4, 2669.41 - both properly overlapped by .42

# %% [markdown]
# #### Aircraft speed
# <div class="alert alert-block alert-success">
# PASS
# <div>

# %%
qc.checkSpeeds(dh, nominalSpeed=60, maxDistance=60, allowance=0.12, plot_flag=True)
# Out:
# Velocities not known - will calculate from positions
# Nominal ground speed 60.0 m/s; allowed 52.8 : 67.2 for < 60.0 m.
#
#  Checked 14 lines and 1 had some short exceedance(s).
#  1 lines failed for exceedance > allowed.
#  Total number of full exceedances = 1.
#
# L 2271.0 too slow for 19.0 sec (990 m), peak exceedance = 52 m/s.
#   From (447099 E 5706876 N) to (447879 E 5707487 N).
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 8 lines failed the spec: 2267.5, 2621.3, 2627.4, 2675.4, 2681.41, 2685.31, 2693.4, 2699.3.
#
# Of these, 2267.5, 2627.4, 2675.4, 2693.4 were previously accepted in DLV003. 2681.41 was marked for re-flight.
#
# 2621.3 - 72 sec but two sections; associated with climbing to clear town of Batesford. ACCEPT
# 2681.41 - 70.5 sec, single section: ACCEPT
# 2685.31 - 78.5 sec but several sections; associated with climbing to clear town of Meredith. ACCEPT
# 2699.3 - within 12.5% of speed: ACCEPT

# %% [markdown]
# #### Data gaps
# <div class="alert alert-block alert-success">
# Pass
# <div>

# %%
qc.checkSpikes(dh, fields=['ATMCOR', 'B100s-267_GEOID', 'B100s-267_GRS80', 'B56s-267_GEOID', 'B56s-267_GRS80', 'EOTCOR', 'FA100s_GEOID', 'FA100s_GRS80', 'FA56s_GEOID', 'FA56s_GRS80', 'FACOR_GEOID', 'FACOR_GRS80', 'FTIME', 'FX', 'FY', 'FZ', 'LAT', 'LATCOR', 'LINE', 'LONG', 'MGA-X', 'MGA-Y', 'MGA-Z', 'MSL-Z', 'STATCOR', 'TACOR', 'V_EAST', 'V_NORTH', 'YEAR'])
# Out:
#   2261.5; TACOR Extremum: 0.46 > 0.35 = 8.00 x STD of 0.04
#   2263.5; TACOR Extremum: 0.24 > 0.19 = 8.00 x STD of 0.02
#   2265.5; TACOR Extremum: 0.21 > 0.15 = 8.00 x STD of 0.02
#   2277.5; TACOR Extremum: 0.13 > 0.13 = 8.00 x STD of 0.02
#   2345.51; EOTCOR Extremum: 11.11 > 11.03 = 8.00 x STD of 1.38
#   2345.51; LAT Extremum: 0.00 > 0.00 = 8.00 x STD of 0.00
#   2345.51; LATCOR Extremum: 0.01 > 0.01 = 8.00 x STD of 0.00
#   2345.51; MGA-Y Extremum: 9.93 > 9.04 = 8.00 x STD of 1.13
#   2359.51; TACOR Extremum: 0.36 > 0.34 = 8.00 x STD of 0.04
#   2601.4; FX Extremum: 53052.42 > 48823.68 = 8.00 x STD of 6102.96
#   2631.3; TACOR Extremum: 0.40 > 0.35 = 8.00 x STD of 0.04
#   2679.3; TACOR Extremum: 0.51 > 0.49 = 8.00 x STD of 0.06
#   2683.42; LONG Extremum: 0.00 > 0.00 = 8.00 x STD of 0.00
#   2683.42; MGA-X Extremum: 6.02 > 5.75 = 8.00 x STD of 0.72
#   2689.3; TACOR Extremum: 0.63 > 0.54 = 8.00 x STD of 0.07
#   2717.3; TACOR Extremum: 0.22 > 0.22 = 8.00 x STD of 0.03
#   2719.4; TACOR Extremum: 0.68 > 0.65 = 8.00 x STD of 0.08
#   2723.4; TACOR Extremum: 0.51 > 0.50 = 8.00 x STD of 0.06
#   2733.4; TACOR Extremum: 0.45 > 0.32 = 8.00 x STD of 0.04
#   2735.41; TACOR Extremum: 0.14 > 0.13 = 8.00 x STD of 0.02

# %% [markdown]
# None of the above spikes are of any concern and all are only just above the arbitrary (and non-contractual) criterion.

# %%
qc.checkGaps(dh)
# Out:
# Checking for all gaps in all 38 channels on all 323 lines.
#
# 0 lines failed.

# %%
qc.checkConstantSlope(dh, ['DOY', 'FLIGHT', 'FTIME', 'LINE', 'YEAR'])
# Out:
# All fields tested were either constant or of constant slope for all lines tested.

# %% [markdown]
# ***

# %% [markdown]
# #### Check GNSS
# <div class="alert alert-block alert-success">
# Pass
# <div>

# %%
qc.checkGNSS(dh, 'NSATS', 'PDOP', 'VDOP', 'HDOP', nsats_min=4, max_pdop=6, 
                  max_hdop=4, max_vdop=4)
# Out:
# In Victoria and South Australia Gravity, checked num sats, PDOP, VDOP and HDOP. Found 0 errors.

# %% [markdown]
# #### Check filtering
# <div class="alert alert-block alert-success">
# PASS
# <div>

# %%
wp.psdLineChannel(dh, '2621.41', 'B100s-267_GEOID', plotTitle='PSD B100s-267_GEOID')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
wp.psdLineChannel(dh, '2621.41', 'B56s-267_GEOID', plotTitle='PSD B56s_267_GEOID')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Grids of 56 and 100 s filtered data are consistent with expectations.<br>
# Line profiles of Bouguer and free-air gravity have shortest distance between nearby peaks at ~80 sec (56 s filter) and ~140 sec (100 s filter), consistent with expectations.<br>
# The power spectra are at least consistent with the expected filtering.

# %% [markdown]
# #### Check levelling
# <div class="alert alert-block alert-success">
# Pass
# <div>

# %% [markdown]
# Reviewed grids. Minor levelling busts (up to $10 \mu m s^{-2}$) seen. Acceptable for field data pre- tie-line levelling.

# %% [markdown]
# #### Check static data
# <div class="alert alert-block alert-success">
# Pass
# <div>

# %%
qc.allChanStats(dh, allChannels=['STATCOR', 'FLIGHT'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Mean values of `STATCOR` are consistent with static readings pre- and post flights. The records of static data show variances well below the requirements.

# %% [markdown]
# #### Check all required deliverables present
# <div class="alert alert-block alert-success">
# PASS
# <div>

# %% [markdown]
# The contract does not discriminate between field and final data but I am satisfied that all data required in field data has been delivered.

# %% [markdown]
# #### Supplied grid inspection
# <div class="alert alert-block alert-success">
# Pass
# <div>

# %%
qc.checkErsHeaders(dh.parent)
# Out:
# Found 4 .ers files ...
# in: /g/data/z67/nfm547/QAQC/AirGravQC_Package/examples/AG/DLV009
# Comparing ERS files against F056a5000-fvd.ers.
# [3961, 2371, 1, -999999.0, 'float32', 0, -999999.0, 'ieee-le', 'WGS84', 'SUTM55']
# Checking file F056a5000.ers
#   Checked OK.
# Checking file B056a5000-fvd.ers
#   Checked OK.
# Checking file B056a5000.ers
#   Checked OK.

# %% [markdown]
# #### Gridding data
# <div class="alert alert-block alert-success">
# PASS
# <div>

# %% [markdown]
# The supplied grids and various grids generated from the database were visually checked. Generally, the grids were good and as expected. Two items of note:
#
# The difference between laser altimeter and radar altimeter ranges shows a couple of odd features: a linear feature and a single isolated dot with differences > 100 m. Inexplicable to me. Some care will be needed to deal with these features before using the generated DEM in terrain corrections.
#
# The gravity grids show some line-parallel striping. This is clearer on the Bouguer data than the free-air because of the dynamic range. It is clearer on the FVD, or on images shaded perpendicular to line direction. It is clearer on data gridded from the database using minimum curvature with small search radius. It is clearer in the north central part of Caravan Area B. Variations of over 1 mGal were seen across stripes so they are significant in amplitude. Many stripes are very long. They can be disappear as the dynamic range of the nearby signal increases but it is possible that some extend the entire length of a line. At least some stripes seem correlated with the gridded STATCOR field so they may represent gravimeter bias changes while airborne. It seems likely that significant improvement might be achieved by a simple amplitude shift. This should happen during tie-line levelling so not of concern in field data.

# %% [markdown]
# #### Atmospheric corrections
# <div class="alert alert-block alert-success">
# Atmospheric corrections: PASS
# <div>

# %%
qc.checkAtmosEffect(dh, 'ATMCOR', GRS80_height='MGA_Z')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Free air corrections
# <div class="alert alert-block alert-success">
# Free air corrections: PASS
# <div>

# %%
qc.checkFreeAirCorr(dh, 'FACOR_GRS80')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Eotvos corrections
# <div class="alert alert-block alert-success">
# Eotvos corrections: PASS
# <div>

# %%
qc.checkEotvosCorr(dh, 'EOTCOR', east_vel='V_EAST', north_vel='V_NORTH')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Latitude corrections (normal gravity)
# <div class="alert alert-block alert-success">
# Latitude corrections: PASS
# <div>

# %%
qc.checkLatCorr(dh, 'LATCOR')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Aircraft acceleration
# <div class="alert alert-block alert-success">
# Aircraft acceleration: PASS
# <div>

# %%
qc.allChanStats(dh,allChannels=['FX', 'FY', 'FZ'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Means and variances are typical for airborne geophysical surveys.
