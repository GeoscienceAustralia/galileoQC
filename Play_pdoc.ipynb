# %%
pdoc ./src/qualityAnalysis.py
# Out:
# Object `./src/qualityAnalysis.py` not found.

# %%
ls ./src
# Out:
# __pycache__/        graphics.py         pointfiles.py       whizzPlot.py
# config.py           gridfiles.py        qualityAnalysis.py

# %%
import pathlib
import sys

# %%
pathlib.Path("./src/qualityAnalysis.py").parents[1]
# Out:
# PosixPath('.')
