# %%
import AirGravQC as qc

# %%
len(dir(qc))
# Out:
# 147

# %%
qc.butter(6, 10.0, fs=40.0)
# Out:
# (array([0.02958822, 0.17752934, 0.44382335, 0.59176447, 0.44382335,
#         0.17752934, 0.02958822]),
#  array([ 1.00000000e+00, -4.99600361e-16,  7.77695962e-01, -2.27302479e-16,
#          1.14199425e-01, -1.35753368e-17,  1.75092596e-03]))

# %%
import AirGravQC.qc as qc

# %%
qc.butter(6, 3.0, fs=24.0)
# Out:
# (array([0.00105165, 0.00630988, 0.0157747 , 0.02103294, 0.0157747 ,
#         0.00630988, 0.00105165]),
#  array([ 1.        , -2.97852993,  4.136081  , -3.25976428,  1.51727884,
#         -0.39111723,  0.04335699]))

# %%
from AirGravQC import qc as qc

# %%
len(dir(qc))
# Out:
# 107

# %%
from AirGravQC.whizzFiles import pointfiles as gw

# %%
from AirGravQC.whizzFiles import read_ers as ers

# %%
from AirGravQC.qc import qcagg

# %%
dir(qcagg)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'butter',
#  'config',
#  'diffGravVturb',
#  'diffNoiseVturb',
#  'groupName',
#  'gw',
#  'h5py',
#  'lfilter',
#  'np',
#  'plt']

# %%
qcagg.butter
# Out:
# 'Whizz Version 1.0'

# %%
qc.qc
